# %%
import os
from dotenv import find_dotenv, load_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_openai import ChatOpenAI
from langchain import hub
from langchain.agents import create_openai_functions_agent
from langchain.agents import AgentExecutor
from langchain.globals import set_verbose, set_debug

def run_langchain_query(verbose=False, debug=False):
    # Set the verbose and debug modes as per the function arguments
    set_verbose(verbose)
    set_debug(debug)

    # Your existing code to set up and run the query
    prompt = hub.pull("hwchase17/openai-functions-agent")
    llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)
    search = TavilySearchResults()
    tools = [search]
    agent = create_openai_functions_agent(llm, tools, prompt)
    agent_executor = AgentExecutor(agent=agent, tools=tools)

    # Execute the query
    return agent_executor.invoke({"input": "what is the weather in San Diego?"})

# %%
# Show verbose and debug output
response = run_langchain_query(verbose=True, debug=True)
print(response)
# Out:
# [chain/start] [1:chain:AgentExecutor] Entering Chain run with input:
# {
#   "input": "what is the weather in San Diego?"
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence] Entering Chain run with input:
# {
#   "input": "what is the weather in San Diego?",
#   "intermediate_steps": []
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad>] Entering Chain run with input:
# {
#   "input": "what is the weather in San Diego?",
#   "intermediate_steps": []
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad> > 4:chain:RunnableParallel<agent_scratchpad>] Entering Chain run with input:
# {
#   "input": "what is the weather in San Diego?",
#   "intermediate_steps": []
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad> > 4:chain:RunnableParallel<agent_scratchpad> > 5:chain:RunnableLambda] Entering Chain run with input:
# {
#   "input": "what is the weather in San Diego?",
#   "intermediate_steps": []
# }
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad> > 4:chain:RunnableParallel<agent_scratchpad> > 5:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": []
# }
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad> > 4:chain:RunnableParallel<agent_scratchpad>] s] Exiting Chain run with output:
# {
#   "agent_scratchpad": []
# }
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad>] s] Exiting Chain run with output:
# {
#   "input": "what is the weather in San Diego?",
#   "intermediate_steps": [],
#   "agent_scratchpad": []
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 6:prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "input": "what is the weather in San Diego?",
#   "intermediate_steps": [],
#   "agent_scratchpad": []
# }
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 6:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "chat",
#     "ChatPromptValue"
#   ],
#   "kwargs": {
#     "messages": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "SystemMessage"
#         ],
#         "kwargs": {
#           "content": "You are a helpful assistant",
#           "additional_kwargs": {}
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "what is the weather in San Diego?",
#           "additional_kwargs": {}
#         }
#       }
#     ]
#   }
# }
# [llm/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 7:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are a helpful assistant\nHuman: what is the weather in San Diego?"
#   ]
# }
# [llm/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 7:llm:ChatOpenAI] [1.00s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "",
#         "generation_info": {
#           "finish_reason": "function_call",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "",
#             "additional_kwargs": {
#               "function_call": {
#                 "arguments": "{\n  \"query\": \"weather in San Diego\"\n}",
#                 "name": "tavily_search_results_json"
#               }
#             }
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 22,
#       "prompt_tokens": 95,
#       "total_tokens": 117
#     },
#     "model_name": "gpt-3.5-turbo",
#     "system_fingerprint": null
#   },
#   "run": null
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 8:parser:OpenAIFunctionsAgentOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 8:parser:OpenAIFunctionsAgentOutputParser] s] Exiting Parser run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "schema",
#     "agent",
#     "AgentActionMessageLog"
#   ],
#   "kwargs": {
#     "tool": "tavily_search_results_json",
#     "tool_input": {
#       "query": "weather in San Diego"
#     },
#     "log": "\nInvoking: `tavily_search_results_json` with `{'query': 'weather in San Diego'}`\n\n\n",
#     "message_log": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "AIMessage"
#         ],
#         "kwargs": {
#           "content": "",
#           "additional_kwargs": {
#             "function_call": {
#               "arguments": "{\n  \"query\": \"weather in San Diego\"\n}",
#               "name": "tavily_search_results_json"
#             }
#           }
#         }
#       }
#     ]
#   }
# }
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence] [1.06s] Exiting Chain run with output:
# [outputs]
# [tool/start] [1:chain:AgentExecutor > 9:tool:tavily_search_results_json] Entering Tool run with input:
# "{'query': 'weather in San Diego'}"
# [tool/end] [1:chain:AgentExecutor > 9:tool:tavily_search_results_json] [12.76s] Exiting Tool run with output:
# "[{'url': 'https://weatherspark.com/h/y/1816/2024/Historical-Weather-during-2024-in-San-Diego-California-United-States', 'content': '2024 Weather History in San Diego California, United States  Cloud Cover in 2024 in San Diego Daily Precipitation in 2024 in San Diego Observed Weather in 2024 in San Diego  Hours of Daylight and Twilight in 2024 in San Diego  Sunrise & Sunset with Twilight and Daylight Saving Time in 2024 in San DiegoLatest Report — 8:51 PM Fri, Jan 12, 2024 11 min ago UTC 04:51 Call Sign KSAN Temp. 51.1 °F cold Precipitation No Report Wind 0.0 mph calm Cloud Cover Partly Cloudy 25,000 ft Raw: KSAN 120451Z 00000KT 10SM SCT250 11/03 A3015 RMK AO2 SLP210 T01060028 $ This report shows the past weather for San Diego, providing a weather history for 2024.'}, {'url': 'https://en.climate-data.org/north-america/united-states-of-america/california/san-diego-714969/t/january-1/', 'content': 'San Diego Weather in January  all information about the weather in San Diego in January:  San Diego weather in January San Diego weather by month // weather averages 12.9 (55.2) 8.8 (47.9) 17.9 (64.3) 54 (2.1)  San Diego weather in January // weather averages Airport close to San DiegoAre you planning a holiday with hopefully nice weather in San Diego in January 2024? Here you can find all information about the weather in San Diego in January: >>Overview: ... 15. January: 13 °C | 55 °F : 18 °C | 65 °F: 9 °C | 48 °F: 15 °C | 59 °F: 0.5 mm | 0.0 inch. 16. January: 13 °C | 56 °F : 18 °C | 64 °F: 9 °C | 49 °F:'}, {'url': 'https://www.sandiegouniontribune.com/news/nation-world/story/2024-01-15/another-day-of-frigid-wind-chills-and-brutal-cold-across-much-of-the-u-s', 'content': 'Jan. 13, 2024 Seeking to woo housing developers, San Diego may loosen rules protecting historic buildings Jan. 14, 2024  Jan. 12, 2024 Homelessness is up along the riverbed since San Diego passed its camping ban Jan. 14, 2024  Breaking News Early morning quake reported off coast of San Diego, no damage reported Jan. 15, 2024 Public Safety  Jan. 14, 2024 Latest Aztecs San Diego State tumbles in AP poll after lopsided loss at New Mexico PadresSnow covers the sign for Texas Street during a winter storm, Monday, Jan. 15, 2024, in Grand Prairie, Texas. (AP Photo/Julio Cortez)'}, {'url': 'https://www.10news.com/weather/san-diegos-weather-forecast-for-january-15-2024-coastal-clouds-continue-to-linger-with-a-mild-day-in-store', 'content': "Actions San Diego's\xa0Weather\xa0Forecast for January 15, 2024: Coastal clouds continue to linger with a mild day in store  this next storm as the jet stream drops south. This weather event would benefit San Diego County, which has many cities  uneventful before a low-pressure system brings much-needed rain to Southern California early Saturday through next  Monday's Highs:Coast: 61-65Inland: 64-69Mountains: 59-65Deserts: 68-70San Diego's Weather Forecast for January 15, 2024: Coastal clouds continue to linger with a mild day in store By: Vanessa Paz Posted at 7:13 AM, Jan 15, 2024 and last updated 7:13..."}]"
# [chain/start] [1:chain:AgentExecutor > 10:chain:RunnableSequence] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 11:chain:RunnableAssign<agent_scratchpad>] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 11:chain:RunnableAssign<agent_scratchpad> > 12:chain:RunnableParallel<agent_scratchpad>] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 11:chain:RunnableAssign<agent_scratchpad> > 12:chain:RunnableParallel<agent_scratchpad> > 13:chain:RunnableLambda] Entering Chain run with input:
# [inputs]
# [chain/end] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 11:chain:RunnableAssign<agent_scratchpad> > 12:chain:RunnableParallel<agent_scratchpad> > 13:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": [
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "AIMessage"
#       ],
#       "kwargs": {
#         "content": "",
#         "additional_kwargs": {
#           "function_call": {
#             "arguments": "{\n  \"query\": \"weather in San Diego\"\n}",
#             "name": "tavily_search_results_json"
#           }
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "FunctionMessage"
#       ],
#       "kwargs": {
#         "name": "tavily_search_results_json",
#         "content": "[{\"url\": \"https://weatherspark.com/h/y/1816/2024/Historical-Weather-during-2024-in-San-Diego-California-United-States\", \"content\": \"2024 Weather History in San Diego California, United States  Cloud Cover in 2024 in San Diego Daily Precipitation in 2024 in San Diego Observed Weather in 2024 in San Diego  Hours of Daylight and Twilight in 2024 in San Diego  Sunrise & Sunset with Twilight and Daylight Saving Time in 2024 in San DiegoLatest Report — 8:51 PM Fri, Jan 12, 2024 11 min ago UTC 04:51 Call Sign KSAN Temp. 51.1 °F cold Precipitation No Report Wind 0.0 mph calm Cloud Cover Partly Cloudy 25,000 ft Raw: KSAN 120451Z 00000KT 10SM SCT250 11/03 A3015 RMK AO2 SLP210 T01060028 $ This report shows the past weather for San Diego, providing a weather history for 2024.\"}, {\"url\": \"https://en.climate-data.org/north-america/united-states-of-america/california/san-diego-714969/t/january-1/\", \"content\": \"San Diego Weather in January  all information about the weather in San Diego in January:  San Diego weather in January San Diego weather by month // weather averages 12.9 (55.2) 8.8 (47.9) 17.9 (64.3) 54 (2.1)  San Diego weather in January // weather averages Airport close to San DiegoAre you planning a holiday with hopefully nice weather in San Diego in January 2024? Here you can find all information about the weather in San Diego in January: >>Overview: ... 15. January: 13 °C | 55 °F : 18 °C | 65 °F: 9 °C | 48 °F: 15 °C | 59 °F: 0.5 mm | 0.0 inch. 16. January: 13 °C | 56 °F : 18 °C | 64 °F: 9 °C | 49 °F:\"}, {\"url\": \"https://www.sandiegouniontribune.com/news/nation-world/story/2024-01-15/another-day-of-frigid-wind-chills-and-brutal-cold-across-much-of-the-u-s\", \"content\": \"Jan. 13, 2024 Seeking to woo housing developers, San Diego may loosen rules protecting historic buildings Jan. 14, 2024  Jan. 12, 2024 Homelessness is up along the riverbed since San Diego passed its camping ban Jan. 14, 2024  Breaking News Early morning quake reported off coast of San Diego, no damage reported Jan. 15, 2024 Public Safety  Jan. 14, 2024 Latest Aztecs San Diego State tumbles in AP poll after lopsided loss at New Mexico PadresSnow covers the sign for Texas Street during a winter storm, Monday, Jan. 15, 2024, in Grand Prairie, Texas. (AP Photo/Julio Cortez)\"}, {\"url\": \"https://www.10news.com/weather/san-diegos-weather-forecast-for-january-15-2024-coastal-clouds-continue-to-linger-with-a-mild-day-in-store\", \"content\": \"Actions San Diego's Weather Forecast for January 15, 2024: Coastal clouds continue to linger with a mild day in store  this next storm as the jet stream drops south. This weather event would benefit San Diego County, which has many cities  uneventful before a low-pressure system brings much-needed rain to Southern California early Saturday through next  Monday's Highs:Coast: 61-65Inland: 64-69Mountains: 59-65Deserts: 68-70San Diego's Weather Forecast for January 15, 2024: Coastal clouds continue to linger with a mild day in store By: Vanessa Paz Posted at 7:13 AM, Jan 15, 2024 and last updated 7:13...\"}]"
#       }
#     }
#   ]
# }
# [chain/end] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 11:chain:RunnableAssign<agent_scratchpad> > 12:chain:RunnableParallel<agent_scratchpad>] s] Exiting Chain run with output:
# [outputs]
# [chain/end] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 11:chain:RunnableAssign<agent_scratchpad>] s] Exiting Chain run with output:
# {
#   "input": "what is the weather in San Diego?",
#   "intermediate_steps": [
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "agent",
#           "AgentActionMessageLog"
#         ],
#         "kwargs": {
#           "tool": "tavily_search_results_json",
#           "tool_input": {
#             "query": "weather in San Diego"
#           },
#           "log": "\nInvoking: `tavily_search_results_json` with `{'query': 'weather in San Diego'}`\n\n\n",
#           "message_log": [
#             {
#               "lc": 1,
#               "type": "constructor",
#               "id": [
#                 "langchain",
#                 "schema",
#                 "messages",
#                 "AIMessage"
#               ],
#               "kwargs": {
#                 "content": "",
#                 "additional_kwargs": {
#                   "function_call": {
#                     "arguments": "{\n  \"query\": \"weather in San Diego\"\n}",
#                     "name": "tavily_search_results_json"
#                   }
#                 }
#               }
#             }
#           ]
#         }
#       },
#       [
#         {
#           "url": "https://weatherspark.com/h/y/1816/2024/Historical-Weather-during-2024-in-San-Diego-California-United-States",
#           "content": "2024 Weather History in San Diego California, United States  Cloud Cover in 2024 in San Diego Daily Precipitation in 2024 in San Diego Observed Weather in 2024 in San Diego  Hours of Daylight and Twilight in 2024 in San Diego  Sunrise & Sunset with Twilight and Daylight Saving Time in 2024 in San DiegoLatest Report — 8:51 PM Fri, Jan 12, 2024 11 min ago UTC 04:51 Call Sign KSAN Temp. 51.1 °F cold Precipitation No Report Wind 0.0 mph calm Cloud Cover Partly Cloudy 25,000 ft Raw: KSAN 120451Z 00000KT 10SM SCT250 11/03 A3015 RMK AO2 SLP210 T01060028 $ This report shows the past weather for San Diego, providing a weather history for 2024."
#         },
#         {
#           "url": "https://en.climate-data.org/north-america/united-states-of-america/california/san-diego-714969/t/january-1/",
#           "content": "San Diego Weather in January  all information about the weather in San Diego in January:  San Diego weather in January San Diego weather by month // weather averages 12.9 (55.2) 8.8 (47.9) 17.9 (64.3) 54 (2.1)  San Diego weather in January // weather averages Airport close to San DiegoAre you planning a holiday with hopefully nice weather in San Diego in January 2024? Here you can find all information about the weather in San Diego in January: >>Overview: ... 15. January: 13 °C | 55 °F : 18 °C | 65 °F: 9 °C | 48 °F: 15 °C | 59 °F: 0.5 mm | 0.0 inch. 16. January: 13 °C | 56 °F : 18 °C | 64 °F: 9 °C | 49 °F:"
#         },
#         {
#           "url": "https://www.sandiegouniontribune.com/news/nation-world/story/2024-01-15/another-day-of-frigid-wind-chills-and-brutal-cold-across-much-of-the-u-s",
#           "content": "Jan. 13, 2024 Seeking to woo housing developers, San Diego may loosen rules protecting historic buildings Jan. 14, 2024  Jan. 12, 2024 Homelessness is up along the riverbed since San Diego passed its camping ban Jan. 14, 2024  Breaking News Early morning quake reported off coast of San Diego, no damage reported Jan. 15, 2024 Public Safety  Jan. 14, 2024 Latest Aztecs San Diego State tumbles in AP poll after lopsided loss at New Mexico PadresSnow covers the sign for Texas Street during a winter storm, Monday, Jan. 15, 2024, in Grand Prairie, Texas. (AP Photo/Julio Cortez)"
#         },
#         {
#           "url": "https://www.10news.com/weather/san-diegos-weather-forecast-for-january-15-2024-coastal-clouds-continue-to-linger-with-a-mild-day-in-store",
#           "content": "Actions San Diego's Weather Forecast for January 15, 2024: Coastal clouds continue to linger with a mild day in store  this next storm as the jet stream drops south. This weather event would benefit San Diego County, which has many cities  uneventful before a low-pressure system brings much-needed rain to Southern California early Saturday through next  Monday's Highs:Coast: 61-65Inland: 64-69Mountains: 59-65Deserts: 68-70San Diego's Weather Forecast for January 15, 2024: Coastal clouds continue to linger with a mild day in store By: Vanessa Paz Posted at 7:13 AM, Jan 15, 2024 and last updated 7:13..."
#         }
#       ]
#     ]
#   ],
#   "agent_scratchpad": [
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "AIMessage"
#       ],
#       "kwargs": {
#         "content": "",
#         "additional_kwargs": {
#           "function_call": {
#             "arguments": "{\n  \"query\": \"weather in San Diego\"\n}",
#             "name": "tavily_search_results_json"
#           }
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "FunctionMessage"
#       ],
#       "kwargs": {
#         "name": "tavily_search_results_json",
#         "content": "[{\"url\": \"https://weatherspark.com/h/y/1816/2024/Historical-Weather-during-2024-in-San-Diego-California-United-States\", \"content\": \"2024 Weather History in San Diego California, United States  Cloud Cover in 2024 in San Diego Daily Precipitation in 2024 in San Diego Observed Weather in 2024 in San Diego  Hours of Daylight and Twilight in 2024 in San Diego  Sunrise & Sunset with Twilight and Daylight Saving Time in 2024 in San DiegoLatest Report — 8:51 PM Fri, Jan 12, 2024 11 min ago UTC 04:51 Call Sign KSAN Temp. 51.1 °F cold Precipitation No Report Wind 0.0 mph calm Cloud Cover Partly Cloudy 25,000 ft Raw: KSAN 120451Z 00000KT 10SM SCT250 11/03 A3015 RMK AO2 SLP210 T01060028 $ This report shows the past weather for San Diego, providing a weather history for 2024.\"}, {\"url\": \"https://en.climate-data.org/north-america/united-states-of-america/california/san-diego-714969/t/january-1/\", \"content\": \"San Diego Weather in January  all information about the weather in San Diego in January:  San Diego weather in January San Diego weather by month // weather averages 12.9 (55.2) 8.8 (47.9) 17.9 (64.3) 54 (2.1)  San Diego weather in January // weather averages Airport close to San DiegoAre you planning a holiday with hopefully nice weather in San Diego in January 2024? Here you can find all information about the weather in San Diego in January: >>Overview: ... 15. January: 13 °C | 55 °F : 18 °C | 65 °F: 9 °C | 48 °F: 15 °C | 59 °F: 0.5 mm | 0.0 inch. 16. January: 13 °C | 56 °F : 18 °C | 64 °F: 9 °C | 49 °F:\"}, {\"url\": \"https://www.sandiegouniontribune.com/news/nation-world/story/2024-01-15/another-day-of-frigid-wind-chills-and-brutal-cold-across-much-of-the-u-s\", \"content\": \"Jan. 13, 2024 Seeking to woo housing developers, San Diego may loosen rules protecting historic buildings Jan. 14, 2024  Jan. 12, 2024 Homelessness is up along the riverbed since San Diego passed its camping ban Jan. 14, 2024  Breaking News Early morning quake reported off coast of San Diego, no damage reported Jan. 15, 2024 Public Safety  Jan. 14, 2024 Latest Aztecs San Diego State tumbles in AP poll after lopsided loss at New Mexico PadresSnow covers the sign for Texas Street during a winter storm, Monday, Jan. 15, 2024, in Grand Prairie, Texas. (AP Photo/Julio Cortez)\"}, {\"url\": \"https://www.10news.com/weather/san-diegos-weather-forecast-for-january-15-2024-coastal-clouds-continue-to-linger-with-a-mild-day-in-store\", \"content\": \"Actions San Diego's Weather Forecast for January 15, 2024: Coastal clouds continue to linger with a mild day in store  this next storm as the jet stream drops south. This weather event would benefit San Diego County, which has many cities  uneventful before a low-pressure system brings much-needed rain to Southern California early Saturday through next  Monday's Highs:Coast: 61-65Inland: 64-69Mountains: 59-65Deserts: 68-70San Diego's Weather Forecast for January 15, 2024: Coastal clouds continue to linger with a mild day in store By: Vanessa Paz Posted at 7:13 AM, Jan 15, 2024 and last updated 7:13...\"}]"
#       }
#     }
#   ]
# }
# [chain/start] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 14:prompt:ChatPromptTemplate] Entering Prompt run with input:
# [inputs]
# [chain/end] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 14:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "chat",
#     "ChatPromptValue"
#   ],
#   "kwargs": {
#     "messages": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "SystemMessage"
#         ],
#         "kwargs": {
#           "content": "You are a helpful assistant",
#           "additional_kwargs": {}
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "what is the weather in San Diego?",
#           "additional_kwargs": {}
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "AIMessage"
#         ],
#         "kwargs": {
#           "content": "",
#           "additional_kwargs": {
#             "function_call": {
#               "arguments": "{\n  \"query\": \"weather in San Diego\"\n}",
#               "name": "tavily_search_results_json"
#             }
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "FunctionMessage"
#         ],
#         "kwargs": {
#           "name": "tavily_search_results_json",
#           "content": "[{\"url\": \"https://weatherspark.com/h/y/1816/2024/Historical-Weather-during-2024-in-San-Diego-California-United-States\", \"content\": \"2024 Weather History in San Diego California, United States  Cloud Cover in 2024 in San Diego Daily Precipitation in 2024 in San Diego Observed Weather in 2024 in San Diego  Hours of Daylight and Twilight in 2024 in San Diego  Sunrise & Sunset with Twilight and Daylight Saving Time in 2024 in San DiegoLatest Report — 8:51 PM Fri, Jan 12, 2024 11 min ago UTC 04:51 Call Sign KSAN Temp. 51.1 °F cold Precipitation No Report Wind 0.0 mph calm Cloud Cover Partly Cloudy 25,000 ft Raw: KSAN 120451Z 00000KT 10SM SCT250 11/03 A3015 RMK AO2 SLP210 T01060028 $ This report shows the past weather for San Diego, providing a weather history for 2024.\"}, {\"url\": \"https://en.climate-data.org/north-america/united-states-of-america/california/san-diego-714969/t/january-1/\", \"content\": \"San Diego Weather in January  all information about the weather in San Diego in January:  San Diego weather in January San Diego weather by month // weather averages 12.9 (55.2) 8.8 (47.9) 17.9 (64.3) 54 (2.1)  San Diego weather in January // weather averages Airport close to San DiegoAre you planning a holiday with hopefully nice weather in San Diego in January 2024? Here you can find all information about the weather in San Diego in January: >>Overview: ... 15. January: 13 °C | 55 °F : 18 °C | 65 °F: 9 °C | 48 °F: 15 °C | 59 °F: 0.5 mm | 0.0 inch. 16. January: 13 °C | 56 °F : 18 °C | 64 °F: 9 °C | 49 °F:\"}, {\"url\": \"https://www.sandiegouniontribune.com/news/nation-world/story/2024-01-15/another-day-of-frigid-wind-chills-and-brutal-cold-across-much-of-the-u-s\", \"content\": \"Jan. 13, 2024 Seeking to woo housing developers, San Diego may loosen rules protecting historic buildings Jan. 14, 2024  Jan. 12, 2024 Homelessness is up along the riverbed since San Diego passed its camping ban Jan. 14, 2024  Breaking News Early morning quake reported off coast of San Diego, no damage reported Jan. 15, 2024 Public Safety  Jan. 14, 2024 Latest Aztecs San Diego State tumbles in AP poll after lopsided loss at New Mexico PadresSnow covers the sign for Texas Street during a winter storm, Monday, Jan. 15, 2024, in Grand Prairie, Texas. (AP Photo/Julio Cortez)\"}, {\"url\": \"https://www.10news.com/weather/san-diegos-weather-forecast-for-january-15-2024-coastal-clouds-continue-to-linger-with-a-mild-day-in-store\", \"content\": \"Actions San Diego's Weather Forecast for January 15, 2024: Coastal clouds continue to linger with a mild day in store  this next storm as the jet stream drops south. This weather event would benefit San Diego County, which has many cities  uneventful before a low-pressure system brings much-needed rain to Southern California early Saturday through next  Monday's Highs:Coast: 61-65Inland: 64-69Mountains: 59-65Deserts: 68-70San Diego's Weather Forecast for January 15, 2024: Coastal clouds continue to linger with a mild day in store By: Vanessa Paz Posted at 7:13 AM, Jan 15, 2024 and last updated 7:13...\"}]"
#         }
#       }
#     ]
#   }
# }
# [llm/start] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 15:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are a helpful assistant\nHuman: what is the weather in San Diego?\nAI: {'arguments': '{\\n  \"query\": \"weather in San Diego\"\\n}', 'name': 'tavily_search_results_json'}\nFunction: [{\"url\": \"https://weatherspark.com/h/y/1816/2024/Historical-Weather-during-2024-in-San-Diego-California-United-States\", \"content\": \"2024 Weather History in San Diego California, United States  Cloud Cover in 2024 in San Diego Daily Precipitation in 2024 in San Diego Observed Weather in 2024 in San Diego  Hours of Daylight and Twilight in 2024 in San Diego  Sunrise & Sunset with Twilight and Daylight Saving Time in 2024 in San DiegoLatest Report — 8:51 PM Fri, Jan 12, 2024 11 min ago UTC 04:51 Call Sign KSAN Temp. 51.1 °F cold Precipitation No Report Wind 0.0 mph calm Cloud Cover Partly Cloudy 25,000 ft Raw: KSAN 120451Z 00000KT 10SM SCT250 11/03 A3015 RMK AO2 SLP210 T01060028 $ This report shows the past weather for San Diego, providing a weather history for 2024.\"}, {\"url\": \"https://en.climate-data.org/north-america/united-states-of-america/california/san-diego-714969/t/january-1/\", \"content\": \"San Diego Weather in January  all information about the weather in San Diego in January:  San Diego weather in January San Diego weather by month // weather averages 12.9 (55.2) 8.8 (47.9) 17.9 (64.3) 54 (2.1)  San Diego weather in January // weather averages Airport close to San DiegoAre you planning a holiday with hopefully nice weather in San Diego in January 2024? Here you can find all information about the weather in San Diego in January: >>Overview: ... 15. January: 13 °C | 55 °F : 18 °C | 65 °F: 9 °C | 48 °F: 15 °C | 59 °F: 0.5 mm | 0.0 inch. 16. January: 13 °C | 56 °F : 18 °C | 64 °F: 9 °C | 49 °F:\"}, {\"url\": \"https://www.sandiegouniontribune.com/news/nation-world/story/2024-01-15/another-day-of-frigid-wind-chills-and-brutal-cold-across-much-of-the-u-s\", \"content\": \"Jan. 13, 2024 Seeking to woo housing developers, San Diego may loosen rules protecting historic buildings Jan. 14, 2024  Jan. 12, 2024 Homelessness is up along the riverbed since San Diego passed its camping ban Jan. 14, 2024  Breaking News Early morning quake reported off coast of San Diego, no damage reported Jan. 15, 2024 Public Safety  Jan. 14, 2024 Latest Aztecs San Diego State tumbles in AP poll after lopsided loss at New Mexico PadresSnow covers the sign for Texas Street during a winter storm, Monday, Jan. 15, 2024, in Grand Prairie, Texas. (AP Photo/Julio Cortez)\"}, {\"url\": \"https://www.10news.com/weather/san-diegos-weather-forecast-for-january-15-2024-coastal-clouds-continue-to-linger-with-a-mild-day-in-store\", \"content\": \"Actions San Diego's Weather Forecast for January 15, 2024: Coastal clouds continue to linger with a mild day in store  this next storm as the jet stream drops south. This weather event would benefit San Diego County, which has many cities  uneventful before a low-pressure system brings much-needed rain to Southern California early Saturday through next  Monday's Highs:Coast: 61-65Inland: 64-69Mountains: 59-65Deserts: 68-70San Diego's Weather Forecast for January 15, 2024: Coastal clouds continue to linger with a mild day in store By: Vanessa Paz Posted at 7:13 AM, Jan 15, 2024 and last updated 7:13...\"}]"
#   ]
# }
# [llm/end] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 15:llm:ChatOpenAI] [1.89s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The weather in San Diego is currently partly cloudy with a temperature of 51.1 °F. There is no precipitation and the wind is calm at 0.0 mph. You can find more information about the weather in San Diego in January [here](https://en.climate-data.org/north-america/united-states-of-america/california/san-diego-714969/t/january-1/).",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The weather in San Diego is currently partly cloudy with a temperature of 51.1 °F. There is no precipitation and the wind is calm at 0.0 mph. You can find more information about the weather in San Diego in January [here](https://en.climate-data.org/north-america/united-states-of-america/california/san-diego-714969/t/january-1/).",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 89,
#       "prompt_tokens": 1042,
#       "total_tokens": 1131
#     },
#     "model_name": "gpt-3.5-turbo",
#     "system_fingerprint": null
#   },
#   "run": null
# }
# [chain/start] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 16:parser:OpenAIFunctionsAgentOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 16:parser:OpenAIFunctionsAgentOutputParser] s] Exiting Parser run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "schema",
#     "agent",
#     "AgentFinish"
#   ],
#   "kwargs": {
#     "return_values": {
#       "output": "The weather in San Diego is currently partly cloudy with a temperature of 51.1 °F. There is no precipitation and the wind is calm at 0.0 mph. You can find more information about the weather in San Diego in January [here](https://en.climate-data.org/north-america/united-states-of-america/california/san-diego-714969/t/january-1/)."
#     },
#     "log": "The weather in San Diego is currently partly cloudy with a temperature of 51.1 °F. There is no precipitation and the wind is calm at 0.0 mph. You can find more information about the weather in San Diego in January [here](https://en.climate-data.org/north-america/united-states-of-america/california/san-diego-714969/t/january-1/)."
#   }
# }
# [chain/end] [1:chain:AgentExecutor > 10:chain:RunnableSequence] [1.97s] Exiting Chain run with output:
# [outputs]
# [chain/end] [1:chain:AgentExecutor] [15.82s] Exiting Chain run with output:
# {
#   "output": "The weather in San Diego is currently partly cloudy with a temperature of 51.1 °F. There is no precipitation and the wind is calm at 0.0 mph. You can find more information about the weather in San Diego in January [here](https://en.climate-data.org/north-america/united-states-of-america/california/san-diego-714969/t/january-1/)."
# }
# {'input': 'what is the weather in San Diego?', 'output': 'The weather in San Diego is currently partly cloudy with a temperature of 51.1 °F. There is no precipitation and the wind is calm at 0.0 mph. You can find more information about the weather in San Diego in January [here](https://en.climate-data.org/north-america/united-states-of-america/california/san-diego-714969/t/january-1/).'}

# %%
# Hide verbose and debug output
response = run_langchain_query(verbose=False, debug=False)
print(response)
